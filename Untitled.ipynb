# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use('science')
import tikzplotlib

# %%
plt.hlines(1/780,0,1)

# %%
def tpl_fix(obj):
    """
    workaround for matplotlib 3.6 renamed legend's _ncol to _ncols, which breaks tikzplotlib
    """
    if hasattr(obj, "_ncols"):
        obj._ncol = obj._ncols
    for child in obj.get_children():
        tpl_fix(child)

def savefig(name):
    tpl_fix(plt.gcf())
    tikzplotlib.save(name+".tex")

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined

# %%
xx = np.linspace(0,6,1000)

# %%
import scipy.integrate as sint

# %%
sint.solve_ivp(lambda _, z: 1j*np.exp(-1j*np.pi*z), [0,4], [0+1j])
# Out:
# /tmp/ipykernel_3746/2534027417.py:1: RuntimeWarning: overflow encountered in exp
#   sint.solve_ivp(lambda _, z: 1j*np.exp(-1j*np.pi*z), [0,4], [0+1j])
# /tmp/ipykernel_3746/2534027417.py:1: RuntimeWarning: invalid value encountered in multiply
#   sint.solve_ivp(lambda _, z: 1j*np.exp(-1j*np.pi*z), [0,4], [0+1j])
# /home/afqt/.local/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:109: RuntimeWarning: invalid value encountered in divide
#   return norm(self._estimate_error(K, h) / scale)
#   message: Required step size is less than spacing between numbers.
#   success: False
#    status: -1
#         t: [ 0.000e+00  4.514e-03 ...  1.376e-02  1.376e-02]
#         y: [[0. +1.j         0. +1.12660578j ... 0.+11.3635343j
#              0.+11.66238973j]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 500
#      njev: 0
#       nlu: 0

# %%
def fun(z):
    return 1j*np.exp(-1j*np.pi*z)*np.cos(np.pi*z)

# %%
def integr(xx, f):
    S = 0j*np.zeros(xx.size)
    for i in range(1, xx.size):
        S[i] = S[i-1] + (xx[i]-xx[i-1])/2*(f(xx[i]) + f(xx[i-1]))
    return S

# %%
plt.plot(xx,np.abs(integr(xx,fun)))

# %%
plt.plot(xx,np.abs(integr(xx,fun)))

# %%
def fun(z):
    return 1j*np.exp(-1j*np.pi*z)*np.sign(np.cos(np.pi*z))
plt.plot(xx,np.abs(integr(xx,fun)))

# %%
def fun(z):
    return 1j*np.exp(-1j*np.pi*z)
def fun2(z):
    return 1j*np.exp(-1j*np.pi*z)*np.sign(np.cos(np.pi*z))
def fun3(z):
    return 1j*np.exp(-1j*np.pi*z)*2/np.pi*np.exp(1j*np.pi*z)
plt.plot(xx,xx)
plt.plot(xx,np.abs(integr(xx,fun)))
plt.plot(xx,np.abs(integr(xx,fun2)))
plt.plot(xx,np.abs(integr(xx,fun3)), linestyle="--")
savefig("QPM")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 11
#       9 plt.plot(xx,np.abs(integr(xx,fun2)))
#      10 plt.plot(xx,np.abs(integr(xx,fun3)), linestyle="--")
# ---> 11 savefig("QPM")
#
# Cell In[27], line 12, in savefig(name)
#      10 def savefig(name):
#      11     tpl_fix(plt.gcf())
# ---> 12     tikzplotlib.save(name+".tex")
#
# File ~/.local/lib/python3.10/site-packages/tikzplotlib/_save.py:262, in save(filepath, encoding, *args, **kwargs)
#     252 def save(filepath: str | Path, *args, encoding: str | None = None, **kwargs):
#     253     """Same as `get_tikz_code()`, but actually saves the code to a file.
#     254
#     255     :param filepath: The file to which the TikZ output will be written.
#    (...)
#     260     :returns: None
#     261     """
# --> 262     code = get_tikz_code(*args, filepath=filepath, **kwargs)
#     263     with open(filepath, "w", encoding=encoding) as f:
#     264         f.write(code)
#
# File ~/.local/lib/python3.10/site-packages/tikzplotlib/_save.py:213, in get_tikz_code(figure, filepath, axis_width, axis_height, textsize, tex_relative_path_to_data, externalize_tables, override_externals, externals_search_path, strict, wrap, add_axis_environment, extra_axis_parameters, extra_groupstyle_parameters, extra_tikzpicture_parameters, extra_lines_start, dpi, show_info, include_disclaimer, standalone, float_format, table_row_sep, flavor)
#     210     _print_pgfplot_libs_message(data)
#     212 # gather the file content
# --> 213 data, content = _recurse(data, figure)
#     215 # Check if there is still an open groupplot environment. This occurs if not
#     216 # all of the group plot slots are used.
#     217 if "is_in_groupplot_env" in data and data["is_in_groupplot_env"]:
#
# File ~/.local/lib/python3.10/site-packages/tikzplotlib/_save.py:352, in _recurse(data, obj)
#     349 data["current axes"] = ax
#     351 # Run through the child objects, gather the content.
# --> 352 data, children_content = _recurse(data, child)
#     354 # populate content and add axis environment if desired
#     355 if data["add axis environment"]:
#
# File ~/.local/lib/python3.10/site-packages/tikzplotlib/_save.py:368, in _recurse(data, obj)
#     366             print("=========================================================")
#     367 elif isinstance(child, mpl.lines.Line2D):
# --> 368     data, cont = _line2d.draw_line2d(data, child)
#     369     content.extend(cont, child.get_zorder())
#     370 elif isinstance(child, mpl.image.AxesImage):
#
# File ~/.local/lib/python3.10/site-packages/tikzplotlib/_line2d.py:57, in draw_line2d(data, obj)
#      54 if alpha is not None:
#      55     addplot_options.append(f"opacity={alpha}")
# ---> 57 linestyle = mypath.mpl_linestyle2pgfplots_linestyle(
#      58     data, obj.get_linestyle(), line=obj
#      59 )
#      60 if linestyle is not None and linestyle != "solid":
#      61     addplot_options.append(linestyle)
#
# File ~/.local/lib/python3.10/site-packages/tikzplotlib/_path.py:472, in mpl_linestyle2pgfplots_linestyle(data, line_style, line)
#     469 default_dashOffset, default_dashSeq = mpl.lines._get_dash_pattern(line_style)
#     471 # get dash format of line under test
# --> 472 dashSeq = line._us_dashSeq
#     473 dashOffset = line._us_dashOffset
#     475 lst = list()
#
# AttributeError: 'Line2D' object has no attribute '_us_dashSeq'
